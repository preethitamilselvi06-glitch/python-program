# %%
x = (1,2,3,4)
x
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# 1 = 5
# 1

# %%
age = 30
txt = f"my name is preethi,im {age} "
print(txt.capitalize())
print(txt.upper())
# Out:
# My name is preethi,im 30
# MY NAME IS PREETHI,IM 30

# %%
print(10>9)
# Out:
# True

# %%
print(0)
# Out:
# 0

# %%
print(bool(0))
print(bool(1))
# Out:
# False
# True

# %%
colours = ["red", "blue", "yellow"]
print(colours[0:2])
print(colours[0])
print(colours[-1])

colors = set((colours))
colors
colours[0] = "orange"
print(colours)
# Out:
# 'colours = ["red", "blue", "yellow"]\nprint(colours[0:2])\nprint(colours[0])\nprint(colours[-1])\n\ncolors = set((colours))\ncolors\ncolours[0] = "orange"\nprint(colours)'

# %%
#add -- append(),insert()
colours.append("blue")
print(colours)
# Out:
# ['orange', 'red', 'blue', 'yellow', 'blue', 'blue', 'blue', 'blue', 'blue']

# %%
colours.insert(1,"red")
print(colours)
# Out:
# ['orange', 'red', 'red', 'red', 'blue', 'yellow', 'blue', 'blue', 'blue', 'blue', 'blue']

# %%
fruits = ["apple", "banana", "mango", "orange", "cherry"]
print(fruits)
# Out:
# ['apple', 'banana', 'mango', 'orange', 'cherry']

# %%
fruits.remove("orange")

# %%
print(fruits)
# Out:
# ['apple', 'banana', 'mango', 'cherry']

# %%
fruits.pop(2)
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruits.clear()

# %%
print(fruits)
# Out:
# []

# %%
fruits.append("orange")

# %%
print(fruits)
# Out:
# ['orange']

# %%
fruits.delete()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 fruits.delete()
#
# AttributeError: 'list' object has no attribute 'delete'

# %%
del fruits

# %%
numbers = [1, 26, 67, 5]
numbers.sort(reverse=True)
print(numbers)
# Out:
# [67, 26, 5, 1]

# %%
x = [1, 2, 3, 4, 5]
x.index[3,'5']
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 2
#       1 x = [1, 2, 3, 4, 5]
# ----> 2 x.index[3,'5']
#       3 print(x)
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
x = [1, 2, 3, 4, 5]
x.insert(3,5)
print(x)
# Out:
# [1, 2, 3, 5, 4, 5]

# %%
x = [1, 2, 3, 4, 5]
print(x[1:3])
x.clear()
# Out:
# [2, 3]

# %%
print(x)
# Out:
# []

# %%
tuple_num = (1,2,3,4,5)
list_num = list((tuple_num))
print(list_num)
list_num[2] = 6
print(list_num)
tuple_num = tuple((list_num))
print(tuple_num)
# Out:
# [1, 2, 3, 4, 5]
# [1, 2, 6, 4, 5]
# (1, 2, 6, 4, 5)

# %%
fruits =["orange","bananaa","apple"]#unpacking
[A,B,C] = fruits
print(A)
# Out:
# orange

# %%
list = [1,2,3]
list
# Out:
# [1, 2, 3]

# %%
set = {1,4,"a",1,"0.7"}
print(4 not in set)
# Out:
# False

# %%
set.add(23)
print(set)
# Out:
# {'a', 1, 4, '0.7', 23}

# %%
set1 = {1,2,3}
set2 = {3,4,5}
print(set1.union(set2))
print(set1.intersection(set2))
print(set1.difference(set2))
print(set2-set1)
print(set1.symmetric_difference(set2))
# Out:
# {1, 2, 3, 4, 5}
# {3}
# {1, 2}
# {4, 5}
# {1, 2, 4, 5}

# %%
car = {"colour":"black","brand":"bmw","prize":"5000000"}
print(car)
# Out:
# {'colour': 'black', 'brand': 'bmw', 'prize': '5000000'}

# %%
print(car["colour"])
# Out:
# black

# %%
print(car["prize"])
# Out:
# 5000000

# %%
x= car.get('brand')
x
y= car.keys()
y
z = car.values()
z
# Out:
# dict_values(['black', 'bmw', '5000000'])

# %%
print(car)
# Out:
# {'colour': 'black', 'brand': 'bmw', 'prize': '5000000'}

# %%
car["prize"]= 450000
car
# Out:
# {'colour': 'black', 'brand': 'bmw', 'prize': 450000}

# %%
print(car)
car["year"]= 2026
car
car.update({"mode":"2026"})
print(car
      )
# Out:
# {'colour': 'black', 'brand': 'bmw', 'prize': 450000, 'year': '2026'}
# {'colour': 'black', 'brand': 'bmw', 'prize': 450000, 'year': 2026, 'mode': '2026'}
